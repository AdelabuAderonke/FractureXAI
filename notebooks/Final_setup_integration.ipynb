# %% [markdown]
# **Clone the repository**

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
if not os.path.exists('/content/FractureXAI'):
    # !git clone https://github.com/AdelabuAderonke/FractureXAI.git /content/FractureXAI
# %cd /content/FractureXAI
# !git pull

# !pip install --no-cache-dir torch torchvision torchaudio --quiet
# !pip install --upgrade --quiet torchao transformers peft accelerate streamlit pyngrok pillow matplotlib

# !python3 -c "import torch, torchvision; print(torch.__version__, torchvision.__version__)"
# !pip show torchao | grep Version

# %% [markdown]
# Load finetuned models

# %%
MODEL_A_PATH = "/content/drive/MyDrive/Dissertation/models/medgemma-4b-it-sft-lora-mendeley-final"
MODEL_B_PATH = "/content/drive/MyDrive/Dissertation/models/medgemma-4b-it-sft-lora-grazpedwri-final"
MODEL_B2_PATH = "/content/drive/MyDrive/Dissertation/models/medgemma-4b-it-sft-lora-grazpedwri-final-second"

# %% [markdown]
# Authenticate Hugging face

# %%
from google.colab import userdata
import os
os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

# %% [markdown]
# Launch app

# %% [markdown]
# Don't run except after every push from vscode

# %%
# in Colab
# !git pull
# !pkill -f streamlit
# !nohup streamlit run app/main.py --server.port 8501 > /content/logs.txt 2>&1 &
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# **Run this**

# %%
# !pkill -f streamlit

# %% [markdown]
# **Wait a moment before running **

# %%
# !nohup streamlit run app/main.py --server.port 8501 > /content/logs.txt 2>&1 &

# %% [markdown]
# Use ngrok to expose the streamlit app

# %% [markdown]
# Kill old tunnels first

# %%
from pyngrok import ngrok

# disconnect everything, cleanly
ngrok.kill()

# %%
ngrok.set_auth_token("Auth_token_from_ngrok_dashboard")  # replace with your ngrok auth token

# %%
public_url = ngrok.connect(8501)
print(public_url)
# Out:
# NgrokTunnel: "https://camera-pusher-wad.ngrok-free.dev" -> "http://localhost:8501"

# %% [markdown]
# To check for error logs

# %%
# !cat /content/logs.txt
# Out:
# ...
#
# 2026-09-16 10:51:24.552 Port 8501 is not available
